# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

from IPython.display import clear_output
clear_output()


# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install ultralytics
clear_output()
from ultralytics import YOLO

# %%
model = YOLO("/kaggle/input/final-training-yolo-v8/yolov8-p6.yaml")
for name, param in model.named_parameters():
    if "model.30.cv3.3.1" not in name and "model.30.cv3.3.2" not in name:
        param.requires_grad = False
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.

# %%
results = model.train(
    data="/kaggle/input/1000-catv-dog/data.yaml",
    epochs=50,
    batch=32,
)
# Out:
# ...
# Ultralytics YOLOv8.2.31 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("path/to/the/best/weight")

for name, param in model.named_parameters():
    if "model.30.cv3.3.1" not in name and "model.30.cv3.3.2" not in name:
        param.requires_grad = False

results = model.train(
    data="/kaggle/input/1000-catv-dog/data.yaml",
    epochs=100,  # Set the total number of epochs to 100
    batch=32,
    device='cuda:0,1'
    resume=True,  # Add the resume=True argument to resume training
)
# Out:
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("/kaggle/input/final-training-yolo-v8/yolov8-p6 _original.yaml")

for name, param in model.named_parameters():
    if "model.30.cv3.3.1" not in name and "model.30.cv3.3.2" not in name:
        param.requires_grad = False

results = model.train(
    data="/kaggle/input/1000-catv-dog/data.yaml",
    epochs=50,
    batch=32,
    device='cuda:0,1',
)
# Out:
# WARNING ⚠️ no model scale passed. Assuming scale='n'.
# Ultralytics YOLOv8.2.30 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
#                                                       CUDA:1 (Tesla T4, 15102MiB)
# ...

# %%
model = YOLO("path/to/your/best.pt/original_architecture")

for name, param in model.named_parameters():
    if "model.30.cv3.3.1" not in name and "model.30.cv3.3.2" not in name:
        param.requires_grad = False

results = model.train(
    data="/kaggle/input/1000-catv-dog/data.yaml",
    epochs=50,
    batch=32,
    device='cuda:0,1',
)
