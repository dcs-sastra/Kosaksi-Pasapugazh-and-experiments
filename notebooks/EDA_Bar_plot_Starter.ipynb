# %%
# !git clone https://github.com/dcs-sastra/Kosaksi-Pasapugazh-and-experiments.git
# Out:
# Cloning into 'Kosaksi-Pasapugazh-and-experiments'...
# remote: Enumerating objects: 573, done.
# remote: Counting objects: 100% (78/78), done.
# remote: Compressing objects: 100% (66/66), done.
# remote: Total 573 (delta 28), reused 29 (delta 8), pack-reused 495
# Receiving objects: 100% (573/573), 123.79 MiB | 21.46 MiB/s, done.
# Resolving deltas: 100% (406/406), done.
# Updating files: 100% (476/476), done.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Kosaksi-Pasapugazh-and-experiments/data/raw/Health - HMIS/2008-2009/2008-2009/All_India.csv")

# %%
df.head()
# Out:
#       Unnamed: 0 Unnamed: 1  \
# 0          State        NaN
# 1  A & N Islands        1.1
# 2  A & N Islands      1.1.1
# 3  A & N Islands        1.2
# 4  A & N Islands        1.3
#
#                                           Unnamed: 2 Unnamed: 3   April  \
# 0                                                NaN        NaN     NaN
# 1  Total number of pregnant women Registered for ANC      TOTAL  1621.0
# 2  Of which Number registered within first trimes...      TOTAL     NaN
# 3      Number of Pregnant women registered under JSY      TOTAL     NaN
# 4  Number of pregnant women received 3 ANC check ...      TOTAL     NaN
#
#       May   June   July  August  September  October  November  December  \
# 0     NaN    NaN    NaN     NaN        NaN      NaN       NaN       NaN
# 1  1047.0  559.0  690.0   547.0        NaN   1397.0    1338.0       NaN
# 2   954.0  487.0  558.0   537.0        NaN   1303.0    1280.0       NaN
# ...

# %% [markdown]
# Whether NaN values denote missing or is it 0?

# %%
df.isna().sum()
# Out:
# Unnamed: 0        0
# Unnamed: 1        1
# Unnamed: 2        1
# Unnamed: 3        1
# April         10231
# May           10212
# June          10256
# July          10318
# August        10249
# September      9962
# October        9523
# November       8957
# December       8871
# January        8186
# February       8474
# March          8036
# Total          6506
# dtype: int64

# %%
df.head(20)
# Out:
#        Unnamed: 0 Unnamed: 1  \
# 0           State        NaN
# 1   A & N Islands        1.1
# 2   A & N Islands      1.1.1
# 3   A & N Islands        1.2
# 4   A & N Islands        1.3
# 5   A & N Islands      1.4.1
# 6   A & N Islands      1.4.2
# 7   A & N Islands        1.5
# 8   A & N Islands      1.6.1
# 9   A & N Islands      1.6.2
# 10  A & N Islands      1.7.1
# 11  A & N Islands      1.7.2
# 12  A & N Islands        1.8
# 13  A & N Islands    2.1.1.a
# 14  A & N Islands    2.1.1.b
# 15  A & N Islands    2.1.1.c
# 16  A & N Islands      2.1.2
# 17  A & N Islands      2.1.3
# 18  A & N Islands        2.2
# 19  A & N Islands      2.2.1
#
#                                            Unnamed: 2 Unnamed: 3   April  \
# 0                                                 NaN        NaN     NaN
# 1   Total number of pregnant women Registered for ANC      TOTAL  1621.0
# 2   Of which Number registered within first trimes...      TOTAL     NaN
# ...

# %%
df = df.rename(columns={'Unnamed: 0': 'state'})

# %%
df_subset = df[df["state"].isin(["Tamil Nadu", "Andhra Pradesh", "Assam", "A & N Islands"])]

# %%
df_subset.head()
# Out:
#            state Unnamed: 1  \
# 1  A & N Islands        1.1
# 2  A & N Islands      1.1.1
# 3  A & N Islands        1.2
# 4  A & N Islands        1.3
# 5  A & N Islands      1.4.1
#
#                                           Unnamed: 2 Unnamed: 3   April  \
# 1  Total number of pregnant women Registered for ANC      TOTAL  1621.0
# 2  Of which Number registered within first trimes...      TOTAL     NaN
# 3      Number of Pregnant women registered under JSY      TOTAL     NaN
# 4  Number of pregnant women received 3 ANC check ...      TOTAL     NaN
# 5  Number of pregnant women given TT1 during curr...      TOTAL     NaN
#
#       May   June   July  August  September  October  November  December  \
# 1  1047.0  559.0  690.0   547.0        NaN   1397.0    1338.0       NaN
# 2   954.0  487.0  558.0   537.0        NaN   1303.0    1280.0       NaN
# 3     NaN    NaN    NaN     NaN        NaN      NaN       NaN       NaN
# ...

# %%
df_subset = df_subset[["state", "Unnamed: 1", "Unnamed: 2", "Total"]]

# %%
df_subset.head()
# Out:
#            state Unnamed: 1  \
# 1  A & N Islands        1.1
# 2  A & N Islands      1.1.1
# 3  A & N Islands        1.2
# 4  A & N Islands        1.3
# 5  A & N Islands      1.4.1
#
#                                           Unnamed: 2   Total
# 1  Total number of pregnant women Registered for ANC  7199.0
# 2  Of which Number registered within first trimes...  5119.0
# 3      Number of Pregnant women registered under JSY     0.0
# 4  Number of pregnant women received 3 ANC check ...     0.0
# 5  Number of pregnant women given TT1 during curr...     0.0

# %%
df['Total'] = df['Total'].fillna(0)

# %%
df[df["Unnamed: 2"] == "Total number of pregnant women Registered for ANC"].plot(x='state', y='Total', kind='bar', ylabel = "Total number of pregnant women Registered for ANC")
# Out:
# <Axes: xlabel='state', ylabel='Total number of pregnant women Registered for ANC'>
